# %%
import pandas as pd
f=pd.read_excel('C:/Users/Amera/Desktop/Data bases/attendance.xls',header=1)
f.head()
# Out:
#                           Total elementary, secondary, and combined elementary/secondary schools  \
# NaN                                             ADA as percent of enrollment
# 1                                                                          2
#    United States ........                                             93.079
# Alabama .................                                            93.8124
# Alaska ..................                                            89.9176
#
#                            Unnamed: 1                   Unnamed: 2  \
# NaN                               NaN  Average hours in school day
# 1                                 NaN                            3
#    United States ........    0.218555                       6.6447
# Alabama .................    1.237261                      7.02852
# Alaska ..................    1.215976                      6.47688
#
#                            Unnamed: 3                   Unnamed: 4  \
# ...

# %%
new_header = f.iloc[0]
f = f[1:]
f.columns = new_header
f.head()
# Out:
# Florida ................. 92.678174    0.741328    6.427490     0.084127     \
# NaN                               NaN          NaN         NaN          NaN
# Georgia .................     93.2662     1.278376     6.79186     0.058118
# Hawaii ..................     90.7213     4.577376     6.25758     0.097959
# Idaho ...................     92.3733     2.269361     6.63155     0.085639
# Illinois ................     93.9705     0.706806     6.50051     0.053929
#
# Florida ................. 184.000000   1.200181    1183.571200  18.817400    \
# NaN                               NaN          NaN         NaN          NaN
# Georgia .................         181     1.038880     1229.21      12.4409
# Hawaii ..................         179     1.573022     1118.16      12.7243
# Idaho ...................         173     2.580303     1142.51      12.9977
# Illinois ................         177     0.297876     1147.29       9.6335
#
# ...

# %%
f.dropna()
# Out:
# Florida ................. 92.678174    0.741328    6.427490     0.084127     \
# Georgia .................     93.2662     1.278376     6.79186     0.058118
# Hawaii ..................     90.7213     4.577376     6.25758     0.097959
# Idaho ...................     92.3733     2.269361     6.63155     0.085639
# Illinois ................     93.9705     0.706806     6.50051     0.053929
# Indiana .................     95.6746     0.510953     6.77208     0.062664
# Iowa ....................     94.7606     0.645329     6.85364     0.088878
# Kansas ..................     95.3508     0.518303     6.98152     0.073274
# Kentucky ................     93.0681     1.893770     6.68771     0.058200
# Louisiana ...............     90.3495     2.310309     7.07677     0.077571
# Maine ...................     90.3036     2.409541     6.47134     0.064845
# Maryland ................     94.1037     0.439791     6.58861     0.072328
# ...

# %%
table = pd.pivot_table(f, values=['ADA as percent of enrollment', 'Average hours in school day','Average days in school year','ADA as percent of enrollment','Average hours in school day','ADA as percent of enrollment','Average hours in school day'])
f.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-701d9eb95905> in <module>
# ----> 1 table = pd.pivot_table(f, values=['ADA as percent of enrollment', 'Average hours in school day','Average days in school year','ADA as percent of enrollment','Average hours in school day','ADA as percent of enrollment','Average hours in school day'])
#       2 f.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      59         for i in values:
#      60             if i not in data:
# ---> 61                 raise KeyError(i)
#      62
#      63         to_filter = []
#
# KeyError: 'ADA as percent of enrollment'

# %%
import pandas as pd
m=pd.read_excel('C:/Users/Amera/Desktop/Data bases/mbta.xlsx',header=1)
m.head()
# Out:
#                mode  2007-01  2007-02   2007-03  2007-04  2007-05   2007-06  \
# 1  All Modes by Qtr      NaN      NaN  1187.653      NaN      NaN  1245.959
# 2              Boat    4.000    3.600    40.000    4.300    4.900     5.800
# 3               Bus  335.819  338.675   339.867  352.162  354.367   350.543
# 4     Commuter Rail  142.200  138.500   137.700  139.500  139.000   143.000
# 5        Heavy Rail  435.294  448.271   458.583  472.201  474.579   477.032
#
#    2007-07  2007-08   2007-09   ...     2011-01  2011-02   2011-03  2011-04  \
# 1      NaN      NaN  1256.571   ...         NaN      NaN  1223.452      NaN
# 2    6.521    6.572     5.469   ...       3.140    3.284     3.674    4.251
# 3  357.519  355.479   372.598   ...     334.958  346.234   380.399  380.446
# 4  142.391  142.364   143.051   ...     128.396  125.463   134.374  134.169
# 5  471.735  461.605   499.566   ...     468.418  504.068   516.730  528.631
#
# ...

# %%
m.isna()
# Out:
#      mode  2007-01  2007-02  2007-03  2007-04  2007-05  2007-06  2007-07  \
# 1   False     True     True    False     True     True    False     True
# 2   False    False    False    False    False    False    False    False
# 3   False    False    False    False    False    False    False    False
# 4   False    False    False    False    False    False    False    False
# 5   False    False    False    False    False    False    False    False
# 6   False    False    False    False    False    False    False    False
# 7   False    False    False    False    False    False    False    False
# 8   False    False    False    False    False    False    False    False
# 9   False    False    False    False    False    False    False    False
# 10  False    False    False    False    False    False    False    False
# 11  False    False    False    False    False    False    False    False
#
#     2007-08  2007-09   ...     2011-01  2011-02  2011-03  2011-04  2011-05  \
# ...

# %%
m.dropna()
# Out:
#                  mode   2007-01   2007-02   2007-03   2007-04   2007-05  \
# 2                Boat     4.000     3.600    40.000     4.300     4.900
# 3                 Bus   335.819   338.675   339.867   352.162   354.367
# 4       Commuter Rail   142.200   138.500   137.700   139.500   139.000
# 5          Heavy Rail   435.294   448.271   458.583   472.201   474.579
# 6          Light Rail   227.231   240.262   241.444   255.557   248.262
# 7        Pct Chg / Yr     0.020    -0.040     0.114    -0.002     0.049
# 8         Private Bus     4.772     4.417     4.574     4.542     4.768
# 9                RIDE     4.900     5.000     5.500     5.400     5.400
# 10  Trackless Trolley    12.757    12.913    13.057    13.444    13.479
# 11              TOTAL  1166.974  1191.639  1204.725  1247.105  1244.755
#
#      2007-06   2007-07   2007-08   2007-09    ...      2011-01   2011-02  \
# 2      5.800     6.521     6.572     5.469    ...        3.140     3.284
# ...

# %%
s=pd.read_csv("C:/Users/Amera/Desktop/Data bases/sales.csv",encoding = "ISO-8859-1")  
s.head()
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
#
#                                           event_name  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# 1      Gorge Camping - dave matthews band - sept 3-7
# 2        Dodge Theatre Adams Street Parking - benise
# 3  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4                      Premier Parking - motley crue
#
# ...

# %%
s.isna()
# Out:
#       Unnamed: 0  event_id  primary_act_id  secondary_act_id  \
# 0          False     False           False             False
# 1          False     False           False             False
# 2          False     False           False             False
# 3          False     False           False             False
# 4          False     False           False             False
# 5          False     False           False             False
# 6          False     False           False             False
# 7          False     False           False             False
# 8          False     False           False             False
# 9          False     False           False             False
# 10         False     False           False             False
# 11         False     False           False             False
# 12         False     False           False             False
# 13         False     False           False             False
# ...

# %%
s.dropna()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, event_id, primary_act_id, secondary_act_id, purch_party_lkup_id, event_name, primary_act_name, secondary_act_name, major_cat_name, minor_cat_name, la_event_type_cat, event_disp_name, ticket_text, tickets_purchased_qty, trans_face_val_amt, delivery_type_cd, event_date_time, event_dt, presale_dt, onsale_dt, sales_ord_create_dttm, sales_ord_tran_dt, print_dt, timezn_nm, venue_city, venue_state, venue_postal_cd_sgmt_1, sales_platform_cd, print_flg, la_valid_tkt_event_flg, fin_mkt_nm, web_session_cookie_val, gndr_cd, age_yr, income_amt, edu_val, edu_1st_indv_val, edu_2nd_indv_val, adults_in_hh_num, married_ind, child_present_ind, home_owner_ind, occpn_val, occpn_1st_val, occpn_2nd_val, dist_to_ven]
# Index: []
#
# [0 rows x 46 columns]

# %%
columns_nun=s.dropna(axis=1)
columns_nun.head()
# Out:
#                event_id        primary_act_id      secondary_act_id  \
# 0  abcaf1adb99a935fc661  43f0436b905bfa7c2eec  b85143bf51323b72e53c
# 1  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794  f53529c5679ea6ca5a48
# 2  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1  b85143bf51323b72e53c
# 3  394cb493f893be9b9ed1  b1ccea01ad6ef8522796  b85143bf51323b72e53c
# 4  55b5f67e618557929f48  91c03a34b562436efa3c  b85143bf51323b72e53c
#
#     purch_party_lkup_id                                         event_name  \
# 0  7dfa56dd7d5956b17587  Xfinity Center Mansfield Premier Parking: Flor...
# 1  4f9e6fc637eaf7b736c2      Gorge Camping - dave matthews band - sept 3-7
# 2  6c2545703bd527a7144d        Dodge Theatre Adams Street Parking - benise
# 3  527d6b1eaffc69ddd882  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4  8bd62c394a35213bdf52                      Premier Parking - motley crue
#
#                            primary_act_name major_cat_name minor_cat_name  \
# ...

# %%
import pandas as pd
n=pd.read_csv('C:/Users/Amera/Desktop/Data bases/null.csv')
n.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
n["MultipleLines"]= "no"
n["PaperlessBilling"]= "yes"
n.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0            no             DSL             No  ...                No
# 1            no             DSL            Yes  ...               Yes
# 2            no             DSL            Yes  ...                No
# 3            no             DSL            Yes  ...               Yes
# 4            no     Fiber optic             No  ...                No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...
